# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitha-bareddy/crop-recommendation-system/blob/main/irrigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt

# Thresholds for decision making
TEMP_THRESHOLD = 35       # °C
HUMIDITY_THRESHOLD = 40   # %
SOIL_MOISTURE_THRESHOLD = 30  # %

# Lists to store data
readings = []
temperature_list = []
humidity_list = []
moisture_list = []
pump_status_list = []

# Generate simulated data
for i in range(20):  # 20 sample readings
    temperature = round(random.uniform(25, 45), 2)
    humidity = round(random.uniform(20, 60), 2)
    soil_moisture = round(random.uniform(10, 50), 2)

    # Decision logic for pump
    if soil_moisture < SOIL_MOISTURE_THRESHOLD and temperature > TEMP_THRESHOLD and humidity < HUMIDITY_THRESHOLD:
        pump_status = "ON"
    else:
        pump_status = "OFF"

    # Append data
    readings.append(i+1)
    temperature_list.append(temperature)
    humidity_list.append(humidity)
    moisture_list.append(soil_moisture)
    pump_status_list.append(pump_status)

# Create DataFrame
df = pd.DataFrame({
    "Reading": readings,
    "Temperature (°C)": temperature_list,
    "Humidity (%)": humidity_list,
    "Soil Moisture (%)": moisture_list,
    "Pump Status": pump_status_list
})

# Display table
print(df)

# Plotting the data
plt.figure(figsize=(12, 6))

plt.plot(df["Reading"], df["Temperature (°C)"], label='Temperature (°C)', color='red', marker='o')
plt.plot(df["Reading"], df["Humidity (%)"], label='Humidity (%)', color='blue', marker='x')
plt.plot(df["Reading"], df["Soil Moisture (%)"], label='Soil Moisture (%)', color='green', marker='s')

plt.axhline(y=TEMP_THRESHOLD, color='red', linestyle='--', label='Temp Threshold')
plt.axhline(y=HUMIDITY_THRESHOLD, color='blue', linestyle='--', label='Humidity Threshold')
plt.axhline(y=SOIL_MOISTURE_THRESHOLD, color='green', linestyle='--', label='Moisture Threshold')

plt.title("Smart Irrigation System - Sensor Readings Simulation")
plt.xlabel("Reading Number")
plt.ylabel("Values")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#     Reading  Temperature (°C)  Humidity (%)  Soil Moisture (%) Pump Status
# 0         1             41.03         37.21              34.67         OFF
# 1         2             33.60         45.90              16.99         OFF
# 2         3             36.08         33.91              41.80         OFF
# 3         4             32.12         23.89              20.98         OFF
# 4         5             29.44         40.32              20.52         OFF
# 5         6             38.18         42.95              41.68         OFF
# 6         7             31.07         47.55              44.49         OFF
# 7         8             36.45         24.93              35.84         OFF
# 8         9             41.26         47.87              29.06         OFF
# 9        10             39.42         23.31              34.97         OFF
# 10       11             38.34         24.70              31.48         OFF
# ...
